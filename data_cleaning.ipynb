# %% [markdown]
# # Preparing the dataset
#
# The goal of this notebook is to prepare a dataset of place names in Durham in order to train a model to generate new names. To do this will require cleaning the dataset using the `pandas` library. Along the way we introduce fundamental techniques in data cleaning.

# %% [markdown]
# ## Loading the raw data
#
# We extract the place names in Durham from the dataset `IPN_GB_2023.csv` by the Office for National Statistics that contains all the place names in the UK.

# %%
import pandas as pd

# Load the CSV file as a DataFrame
df = pd.read_csv('IPN_GB_2023.csv', encoding='latin-1')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    placeid   place22cd    placesort          place22nm  splitind descnm  \
# 0      382  IPN0000419       achill           A' Chill         0    LOC
# 1    17379  IPN0018256  crianlarich  A' Chrìon Làraich         0    LOC
# 2    26626  IPN0027987    glasphein  A' Glas Pheighinn         0    LOC
# 3    46448  IPN0048777         moss      A' Mhointeach         0    LOC
# 4     6291  IPN0006615    blackpark   A' Phairce Dhubh         0    LOC
#
#          ctyhistnm    cty61nm   cty91nm               ctyltnm  ...    eer22cd  \
# 0      Argyllshire  Inverness  Highland             Inverness  ...  S15000001
# 1       Perthshire      Perth   Central  Stirling and Falkirk  ...  S15000001
# 2  Inverness-shire  Inverness  Highland     Ross and Cromarty  ...  S15000001
# 3  Inverness-shire  Inverness  Highland             Inverness  ...  S15000001
# 4  Inverness-shire  Inverness  Highland     Ross and Cromarty  ...  S15000001
#
#     eer22nm    pfa22cd   pfa22nm      gridgb1m  gridgb1e  gridgb1n grid1km  \
# 0  Scotland  S23000009  Scotland  1.272131e+12  127213.0  805291.0  NG2705
# 1  Scotland  S23000009  Scotland  2.386251e+12  238625.0  725335.0  NN3825
# 2  Scotland  S23000009  Scotland  1.180241e+12  118024.0  850126.0  NG1850
# 3  Scotland  S23000009  Scotland  1.679981e+12  167998.0  768309.0  NM6768
# 4  Scotland  S23000009  Scotland  1.647191e+12  164719.0  823108.0  NG6423
#
#          lat      long
# 0  57.057719 -6.500908
# 1  56.392697 -4.615953
# 2  57.453604 -6.702876
# 3  56.748563 -5.796222
# 4  57.238077 -5.900833
#
# [5 rows x 44 columns]

# %% [markdown]
# From the dataframe `df` we only want the place names in County Durham. This is easy to do in `pandas`.

# %%
# extract all names that are in County Durham
durham_df = df[df['ctyhistnm'] == 'Durham']

# create a dataframe of all place names in Durham
durham_df = pd.Series(durham_df['place22nm'])
durham_df.name = None # removes the column name from the series object

# %% [markdown]
# ## A first look at `durham_df`
#
# A first step is to have a quick look at our data series `durham_df` using `.head()`.

# %%
durham_df.head()
# Out:
# 765           Addison
# 782     Adelaide Bank
# 1002          Aislaby
# 1008          Aislaby
# 1030           Albany
# dtype: object

# %% [markdown]
# We already see that there are duplicate entries in `durham_df`. To remove duplicate entries we use `.drop_duplicates()`.

# %%
print('length of durham_df before removing duplicates: ', len(durham_df))
durham_df = durham_df.drop_duplicates()
print('length of durham_df after removing duplicates: ', len(durham_df))
# Out:
# length of durham_df before removing duplicates:  2047
# length of durham_df after removing duplicates:  1446

# %% [markdown]
# A large percentage of `durham_df` was duplicates and so we have significantly simplified our data set.

# %% [markdown]
# ## Removing unnecessary elements in names
#
# To ensure our input to the model is high quality we need to remove superfluous parts of place names. For example, scanning through the data we see that certain place names are appended with the string `', unparished area'` which appears to be an artefact in how the data was originally stored. We see these entries below.

# %%
result = durham_df[durham_df.str.contains(', unparished area')]
print(result)
# Out:
# 24176       County Durham, unparished area
# 27112          Darlington, unparished area
# 37326           Gateshead, unparished area
# 43175          Hartlepool, unparished area
# 86693      South Tyneside, unparished area
# 89886    Stockton-on-Tees, unparished area
# 91432          Sunderland, unparished area
# dtype: object

# %% [markdown]
# To remove the unnecessary part of the string we can use `.str.replace` to replace the unwanted string with an empty string.

# %%
durham_df = durham_df.str.replace(', unparished area', '').str.strip()

# %%
result = durham_df[durham_df.str.contains(', unparished area')]
print(result)
# Out:
# Series([], dtype: object)

# %% [markdown]
# ## Using regular expressions to clean entries
#
# Similarly, when checking what place names contain `Durham` we see see some are appended with `(County Durham)` which is unnecessary.

# %%
result = durham_df[durham_df.str.contains('Durham')]
print(result)
# Out:
# 11902        Brandon (County Durham)
# 20119        Chilton (County Durham)
# 20949                 City of Durham
# 24176                  County Durham
# 24182                  County Durham
# 29968                   Durham South
# 29969                    Durham, Old
# 29970                         Durham
# 30397      Easington (County Durham)
# 66335         Murton (County Durham)
# 71127                     Old Durham
# 83936       Sherburn (County Durham)
# 88986        Stanley (County Durham)
# 104113     Whitehill (County Durham)
# 105046    Willington (County Durham)
# dtype: object

# %% [markdown]
# We use `str.replace` to replace the unnecessary inlcusion of `(County Durham)` in some entries. Note that `(Hartlepool)` is included in some entries and we remove these similarly.

# %%
durham_df = durham_df.str.replace(r' \(County Durham\)', '').str.strip()
durham_df = durham_df.str.replace(r' \(Hartlepool\)', '').str.strip()
# Out:
# /var/folders/13/mhcgs5hj0m1_7hh70dyxjqg80000gn/T/ipykernel_13187/2996644441.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   durham_df = durham_df.str.replace(r' \(County Durham\)', '').str.strip()
# /var/folders/13/mhcgs5hj0m1_7hh70dyxjqg80000gn/T/ipykernel_13187/2996644441.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   durham_df = durham_df.str.replace(r' \(Hartlepool\)', '').str.strip()

# %%
result = durham_df[durham_df.str.contains('Durham')]
print(result)
# Out:
# 20949    City of Durham
# 24176     County Durham
# 24182     County Durham
# 29968      Durham South
# 29969       Durham, Old
# 29970            Durham
# 71127        Old Durham
# dtype: object

# %% [markdown]
# We have removed all instances of place names that are appended with `(County Durham)`. Observe that there are two entries for `County Durham` of which neither we want to keep. Moreover, our local knowledge of Durham tells us that `Durham South` and `City of Durham` are not distinct from `Durham`.

# %%
durham_df = durham_df[durham_df != 'City of Durham']
durham_df = durham_df[durham_df != 'County Durham']
durham_df = durham_df[durham_df != 'Durham South']

# %%
result = durham_df[durham_df.str.contains('Durham')]
print(result)
# Out:
# 29969    Durham, Old
# 29970         Durham
# 71127     Old Durham
# dtype: object

# %% [markdown]
# ## Rearranging entries in `durham_df`
#
# `Durham, Old` and `Old Durham` are exactly the same place! Additionally, we want to take the convention that we do not have commas in our dataset and just swap the string elements before and after a comma. We can view the entries in `durham_df` that we need to perform this on.

# %%
result = durham_df[durham_df.str.contains(',')]
print(result)
# Out:
# 3755                                    Auckland, St. Helen
# 3756                                         Auckland, West
# 3980                                       Aycliffe, Newton
# 3981                                       Aycliffe, School
# 5280                                         Barmston, High
#                                 ...
# 103556                                           Wham, High
# 105056                                      Willington, Low
# 105472                                         Wingate, Old
# 105563                                         Winning, Esh
# 106176    Wolsingham Park Moor lands cmn to Stanhope, To...
# Length: 164, dtype: object

# %% [markdown]
# The following code find elements of `durham_df` that contain a comma, removes the comma and swaps the elements of the string either side of it around.

# %%
ix = durham_df.str.contains(',')

durham_df.loc[ix] = durham_df.loc[ix].str.split(', ').apply(lambda x: f'{x[1]} {x[0]}')

# %%
print(durham_df[ix])
# Out:
# 3755                                     St. Helen Auckland
# 3756                                          West Auckland
# 3980                                        Newton Aycliffe
# 3981                                        School Aycliffe
# 5280                                          High Barmston
#                                 ...
# 103556                                            High Wham
# 105056                                       Low Willington
# 105472                                          Old Wingate
# 105563                                          Esh Winning
# 106176    Tow Law and Wolsingham Wolsingham Park Moor la...
# Length: 164, dtype: object

# %% [markdown]
# The last entry looks rather suspicious! It turns out that there is indeed a parish called `Wolsingham Park Moor lands cmn to Stanhope, Tow Law and Wolsingham` that corresponds to an area around Wolsingham, Tow Law and Stanhope. However, Wolsingham, Tow Law and Stanhope are all in `durham_df` and we can safely remove this strange entry. Inspecting `durham_df` further, there are two similar entries that we also remove.

# %%
durham_df = durham_df[durham_df != 'Tow Law and Wolsingham Wolsingham Park Moor lands cmn to Stanhope']
durham_df = durham_df[durham_df != 'Lands Common to Brancepeth and Brandon and Byshottles']
durham_df = durham_df[durham_df != 'Lynesack and Softley and South Bedburn Lands common to Hamsterley']

# %% [markdown]
# ## Deeper into `durham_df`
#
# Inspecting `durham_df` we find `Northern Parishes` and `Western Parishes` that correspond to areas rather than places. Consequently we remove these from `durham_df`.

# %%
durham_df = durham_df[durham_df != 'Northern Parishes']
durham_df = durham_df[durham_df != 'Western Parishes']

# %% [markdown]
# Parsing through `durham_df` we see many entries that are either misspelt, contain superfluous details or do not exist according to searches online. We remove these entries and briefly justify them with comments.

# %%
durham_df = durham_df[durham_df != 'Auk Side'] # already has Aukside
durham_df = durham_df[durham_df != 'Carlton (Stockton-on-Tees)']
durham_df = durham_df[durham_df != 'Chilton Buildings'] # old name for Chilton
durham_df = durham_df[durham_df != 'Claravale'] # Should be Clara Vale which is in durham_df
durham_df = durham_df[durham_df != 'Copthill'] # Copt Hill
durham_df = durham_df[durham_df != 'Cornforth Lane'] # Cornforth, can't find anything other than a street
durham_df = durham_df[durham_df != 'Dunston Hill and Whickham East'] # can't find Whickham East, Dunston Hill is already there
durham_df = durham_df[durham_df != 'Eden and Lyvennet Vale'] # can't find Lyvennet Vale but Eden is there
durham_df = durham_df[durham_df != 'Fighting Cocks'] # a pub?
durham_df = durham_df[durham_df != 'Hardwick and Salters Lane'] # can't find Salters Lane
durham_df = durham_df[durham_df != 'Houghton le Side'] # Houghton-le-Side is already in durham_df
durham_df = durham_df[durham_df != 'Mill Dam Valley'] # seems not to be a place
durham_df = durham_df[durham_df != 'Middleton in Teesdale'] # Middleton-in-Teesdale already in durham_df
durham_df = durham_df[durham_df != 'Northumberland'] # that's a county!
durham_df = durham_df[durham_df != 'Nova Scotia'] # ??
durham_df = durham_df[durham_df != 'Number One'] # ?????
durham_df = durham_df[durham_df != 'Pelaw Main'] # same as Pelaw
durham_df = durham_df[durham_df != 'Heworth Lane'] # can't find on map
durham_df = durham_df[durham_df != 'Heworth Shore'] # can't find
durham_df = durham_df[durham_df != 'Upper Heworth'] # same as High Heworth
durham_df = durham_df[durham_df != 'Crookhill and Stella Ryton'] # can't find
durham_df = durham_df[durham_df != 'Sherburn Road'] # can't find
durham_df = durham_df[durham_df != 'West Sherburn'] # can't find
durham_df = durham_df[durham_df != 'Stillington (Stockton-on-Tees)'] # don't want two
durham_df = durham_df[durham_df != 'Whitburn (South Tyneside)']
durham_df = durham_df[durham_df != 'Whinny Hill'] # Whinney hill
durham_df = durham_df[durham_df != 'Witton le Wear'] # already has Witton-le-Wear

# %% [markdown]
# Another issue is the same place has multiple entries with directions like north attached. For the examples where this does not actually correspond to a distinct place, we will remove them.

# %%
durham_df = durham_df[durham_df != 'Barnard Castle East']
durham_df = durham_df[durham_df != 'Barnard Castle West']
durham_df = durham_df[durham_df != 'Chester-le-Street East']
durham_df = durham_df[durham_df != 'Chester-le-Street North']
durham_df = durham_df[durham_df != 'Chester-le-Street South']
durham_df = durham_df[durham_df != 'Chester-le-Street West Central']
durham_df = durham_df[durham_df != 'Consett North']
durham_df = durham_df[durham_df != 'Consett South']
durham_df = durham_df[durham_df != 'North Grindon']
durham_df = durham_df[durham_df != 'South Grindon']
durham_df = durham_df[durham_df != 'West Hartlepool']
durham_df = durham_df[durham_df != 'The Hartlepools']
durham_df = durham_df[durham_df != 'Norton North']
durham_df = durham_df[durham_df != 'Norton South']
durham_df = durham_df[durham_df != 'Norton West']
durham_df = durham_df[durham_df != 'Upper Heworth'] # same as High Heworth
durham_df = durham_df[durham_df != 'Washington North']
durham_df = durham_df[durham_df != 'Washington South']
durham_df = durham_df[durham_df != 'Washington Station']
durham_df = durham_df[durham_df != 'Washington West']

# %% [markdown]
# We manually change entries that are inaccurate or misleading. I know `Newton Hall` well and `Framwellgate` refers to `Framwellgate Moor` that is already included in `durham_df`.

# %%
durham_df[durham_df == 'Framwellgate and Newton Hall'] = 'Newton Hall' 
durham_df[durham_df == 'Old (or Painshaw) Penshaw'] = 'Old Penshaw'

# %% [markdown]
# Throughout `durham_df` there is an inconsistent usage of `St` and `St.` in the names of places as an abbreviation of Saint. We take the convention to use `St` and can implement this with regular expressions.

# %%
durham_df = durham_df.str.replace(r'St\.', 'St')
# Out:
# /var/folders/13/mhcgs5hj0m1_7hh70dyxjqg80000gn/T/ipykernel_13187/54092080.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   durham_df = durham_df.str.replace(r'St\.', 'St')

# %% [markdown]
# Another inconsistency is the use of both `&` and `and`. We choose to use the string `and`.

# %%
durham_df = durham_df.str.replace(r'&', 'and')

# %%
result = durham_df[durham_df.str.contains(' and ')]
print(result)
# Out:
# 1663               Alston and Fellside
# 3976      Aycliffe North and Middridge
# 4875            Bank Top and Lascelles
# 6294                  Beacon and Bents
# 7344             Benwell and Scotswood
#                       ...
# 103760    Whickham South and Sunniside
# 103866            Whitburn and Marsden
# 105053          Willington and Hunwick
# 105433       Windy Nook and Whitehills
# 105546          Winlaton and High Spen
# Length: 61, dtype: object

# %% [markdown]
# Many entries that contain `and` will have both parts also contained in `durham_df`. For these we will remove the entry with `and`.

# %%
# Find entries in the form 'X and Y' that are both present in the Series
entries_to_remove = []
for entry in durham_df:
    parts = entry.split(' and ')
    if len(parts) == 2 and parts[0] in durham_df.values and parts[1] in durham_df.values:
        entries_to_remove.append(entry)

# Remove the identified entries from the Series
durham_df = durham_df[~durham_df.isin(entries_to_remove)]

# %% [markdown]
# After cleaning some entries may be duplicated again, so to be safe we remove any duplicates one last time.

# %%
print('length of durham_df before removing duplicates again: ', len(durham_df))
durham_df = durham_df.drop_duplicates()
print('length of durham_df after removing duplicates again: ', len(durham_df))
# Out:
# length of durham_df before removing duplicates again:  1349
# length of durham_df after removing duplicates again:  1182

# %% [markdown]
# For the final version we relabel the indices from 1 to `len(durham_df)` for clarity.

# %%
durham_df.index = range(1, len(durham_df) + 1)

# %% [markdown]
# One final look before saving!

# %%
durham_df = durham_df.str.lower()

# %%
print(durham_df.to_string(max_rows=None))
# Out:
# 1                            addison
# 2                      adelaide bank
# 3                            aislaby
# 4                             albany
# 5                        albert hill
# 6                aldin grange bridge
# 7                 allendale cottages
# 8                         allensford
# 9                       allenshields
# 10                allerdene colliery
# 11                         allerdene
# 12               alston and fellside
# 13                       alum waters
# 14                    annfield plain
# 15                 archdeacon newton
# 16                         ashbrooke
# 17                     auckland park
# 18                 st helen auckland
# 19                     west auckland
# 20                           aukside
# 21                       auton stile
# 22                       axwell park
# 23                     aycliffe east
# 24      aycliffe north and middridge
# 25                  aycliffe village
# 26                     aycliffe west
# 27                   newton aycliffe
# 28                   school aycliffe
# 29                       ayre's quay
# 30                             ayton
# 31            bank top and lascelles
# 32                          bank top
# 33                          bankside
# 34                          bar moor
# 35                        barley mow
# 36                            barlow
# 37                          barmpton
# 38                     high barmston
# 39                   middle barmston
# 40                          barmston
# 41                    barnard castle
# 42                       barnes park
# 43                            barnes
# 44                      bates houses
# 45                      beacon lough
# 46                  beacon and bents
# 47                      beamish park
# 48                           beamish
# 49                         bear park
# 50                 bearpark colliery
# 51                          bearpark
# 52                     beaumont hill
# 53                           bedburn
# 54               bede trading estate
# 55                              bede
# 56                         beechburn
# 57                        beechgrove
# 58                      high belasis
# 59                    middle belasis
# 60                          bellevue
# 61                           belmont
# 62                      benfieldside
# 63                           bensham
# 64                       south bents
# 65             benwell and scotswood
# 66                       bewick main
# 67                     cowpen bewley
# 68                      biddick hall
# 69            biddick and all saints
# 70                     north biddick
# 71                           biddick
# 72                 bildershaw grange
# 73                        bildershaw
# 74                         bill quay
# 75                billingham central
# 76                   billingham east
# 77                  billingham north
# 78                  billingham south
# 79                   billingham west
# 80                        billingham
# 81                         billy row
# 82                 binchester blocks
# 83                   binchester moor
# 84                        binchester
# 85                           birtley
# 86              bishop auckland town
# 87                   bishop auckland
# 88                  bishop middleham
# 89                      bishopsgarth
# 90                         bishopton
# 91                   bishopwearmouth
# 92                   north bitchburn
# 93                       black banks
# 94                    blackburn fell
# 95                         blackburn
# 96                    west blackdene
# 97                         blackfell
# 98                         blackfyne
# 99                         blackgate
# 100               blackhall colliery
# 101                   blackhall mill
# 102                  blackhall rocks
# 103                       blackhalls
# 104                        blackhill
# 105                       blackhouse
# 106                         blackton
# 107                        blackwell
# 108                     blaydon burn
# 109                   blaydon haughs
# 110                          blaydon
# 111                     bleach green
# 112                     bloemfontein
# 113                    blue quarries
# 114                          bog row
# 115                            bolam
# 116                  bolden colliery
# 117                      east bolden
# 118                  boldon colliery
# 119                      west boldon
# 120                           boldon
# 121                       bolts burn
# 122                  boundary houses
# 123                        bournmoor
# 124                          bowburn
# 125                     bowden close
# 126                       bowesfield
# 127                          bowlees
# 128            bradbury and the isle
# 129                         bradbury
# 130                 bradley cottages
# 131                       brafferton
# 132                   new brancepeth
# 133                       brancepeth
# 134                          brandon
# 135                     brandon hill
# 136                  brandon village
# 137           brandon and byshottles
# 138                     east brandon
# 139                        branksome
# 140                         brasside
# 141                     breckon hill
# 142                       the briary
# 143                      brick garth
# 144                       bridge end
# 145                      bridge hill
# 146                          bridges
# 147                         brierton
# 148          brinkburn and faverdale
# 149                   brockley whins
# 150                        brookside
# 151                       broom farm
# 152                       broom hill
# 153                      broom house
# 154                       broom park
# 155                        the broom
# 156                        broompark
# 157                  broomside house
# 158                       brotherlee
# 159                     gilpin brown
# 160                          browney
# 161                       brusselton
# 162                     bryan's leap
# 163                      bunker hill
# 164                      burdon moor
# 165                    little burdon
# 166                           burdon
# 167                        burn hall
# 168                        burn hill
# 169                      burn valley
# 170                     low burnhall
# 171                         burnhope
# 172                   high burnigill
# 173                    low burnigill
# 174                      burnopfield
# 175                      north burns
# 176                         burnside
# 177                     burnt houses
# 178                     burtree ford
# 179                       bushblades
# 180                     butcher race
# 181                   east butsfield
# 182                     butterknowle
# 183                       butterwick
# 184                         byermoor
# 185                      byers garth
# 186                      byers green
# 187                            byker
# 188                   old california
# 189          callerton and throckley
# 190                    campbell park
# 191                           canada
# 192                      canney hill
# 193                         carlbury
# 194                      carley hill
# 195                          carlton
# 196                        carr hill
# 197                        carrville
# 198                       old cassop
# 199           cassop-cum-quarrington
# 200                           cassop
# 201                      castle dene
# 202                      castle eden
# 203                           castle
# 204                       castleside
# 205                       castletown
# 206                        catchgate
# 207                        cauldwell
# 208                           causey
# 209                   central estate
# 210                          central
# 211                  st johns chapel
# 212                          charlaw
# 213                    chartershaugh
# 214                     chester moor
# 215                chester-le-street
# 216                          chilton
# 217                     chilton lane
# 218                     chilton moor
# 219                     west chilton
# 220             chiltons lane estate
# 221                         chopwell
# 222                         chowdene
# 223                    church kelloe
# 224                       clara vale
# 225                clarence cottages
# 226                    high clarence
# 227                    port clarence
# 228                  clavering place
# 229                          claxton
# 230                   cleadon estate
# 231                     cleadon park
# 232                          cleadon
# 233                   south cleatlam
# 234                         cleatlam
# 235                      close house
# 236                      clough dene
# 237                        coalburns
# 238               coatham mundeville
# 239                      cobeys carr
# 240                      cocken wood
# 241                        cockerton
# 242                        cockfield
# 243                     cockton hill
# 244                    cold hesledon
# 245                         coldwell
# 246                        cole hill
# 247                          college
# 248                       collierley
# 249                     colliery row
# 250                         columbia
# 251                          consett
# 252                           copley
# 253                            coppy
# 254                        copt hill
# 255                        cornforth
# 256                        cornriggs
# 257                 cornsay colliery
# 258                          cornsay
# 259                       coronation
# 260                     coundon gate
# 261                   coundon grange
# 262                      new coundon
# 263                          coundon
# 264                         cowshill
# 265                        cox green
# 266                           coxhoe
# 267                         craghead
# 268                  crake scar farm
# 269                        crawcrook
# 270                     crawley side
# 271                      crawleyside
# 272                 tindale crescent
# 273                     crimdon park
# 274                          crimdon
# 275                   croft on heugh
# 276                 crofton on heugh
# 277                            crook
# 278                   crookgate bank
# 279                        crookgate
# 280                        crookhall
# 281                        crookhill
# 282                  neville's cross
# 283                   crossgate moor
# 284                       crow howle
# 285                croxdale colliery
# 286                         croxdale
# 287                    daddry shield
# 288                   daddry shields
# 289                       daisy hill
# 290                      dalton hill
# 291                    dalton piercy
# 292                   dalton-le-dale
# 293                     dan's castle
# 294                       darlington
# 295                  dawdon colliery
# 296                           dawdon
# 297                         de bruce
# 298                        deaf hill
# 299                        dean bank
# 300                     deanery view
# 301                            deans
# 302                          deckham
# 303                         deerness
# 304                      delves lane
# 305                           delves
# 306                      dene bridge
# 307                      dene valley
# 308                    etherley dene
# 309                         deneside
# 310                           denton
# 311                         deptford
# 312                 derwent cottages
# 313                    derwent haugh
# 314                      derwentside
# 315                       dike heads
# 316                           dipton
# 317                          donwell
# 318                         downhill
# 319                        low downs
# 320                     doxford park
# 321                          doxford
# 322               dragonville estate
# 323                       drinkfield
# 324                          dryburn
# 325                     high dubmire
# 326                          dubmire
# 327                     dunston hill
# 328                          dunston
# 329                       old durham
# 330                           durham
# 331                       dyke house
# 332            eaglescliffe junction
# 333                     eaglescliffe
# 334                        easington
# 335               easington colliery
# 336                   easington lane
# 337                    easington lea
# 338                easington village
# 339                   east blackdene
# 340                      east boldon
# 341             east castle colliery
# 342                      east castle
# 343                   east gateshead
# 344                    east hartburn
# 345                  east hedleyhope
# 346                  east herrington
# 347                       east howle
# 348                      east jarrow
# 349                         east kyo
# 350                         east law
# 351                      east layton
# 352                         east lea
# 353                     east rainton
# 354                       east shaws
# 355                     east stanley
# 356                   east sunniside
# 357                    east thickley
# 358          east and west newbiggin
# 359                       eastbourne
# 360                         eastgate
# 361                          eastlea
# 362                        ebchester
# 363                             eden
# 364                         edge end
# 365                         the edge
# 366                      edmondbyers
# 367                  edmondsley fell
# 368                  west edmondsley
# 369                       edmondsley
# 370                       egglesburn
# 371                     egglescliffe
# 372                        eggleston
# 373                    eighton banks
# 374                          eighton
# 375                       eldon lane
# 376                        old eldon
# 377                            eldon
# 378                   elemore grange
# 379                     elemore vale
# 380                         elm tree
# 381                      elstob hill
# 382                           elstob
# 383                            elton
# 384              elvet and gilesgate
# 385                        new elvet
# 386                           elwick
# 387                         embleton
# 388                   great eppleton
# 389                  little eppleton
# 390                         eppleton
# 391                           escomb
# 392                        esh laude
# 393                      esh winning
# 394                              esh
# 395               esperley lane ends
# 396                    etherley moor
# 397                     low etherley
# 398                         etherley
# 399                       ettersgill
# 400                    evenwood gate
# 401              evenwood and barony
# 402                         evenwood
# 403                        fairfield
# 404               farewell hall west
# 405                       farringdon
# 406                         fatfield
# 407                        faverdale
# 408                         feethams
# 409                         low fell
# 410                         fellgate
# 411                    felling shore
# 412                     high felling
# 413                      low felling
# 414                          felling
# 415                         fellside
# 416                     fence houses
# 417                          fenhall
# 418                fens and greatham
# 419                         the fens
# 420                ferryhill station
# 421                        ferryhill
# 422                   fieldon bridge
# 423                      findon hill
# 424                         fir tree
# 425                       firth moor
# 426                         fishburn
# 427                      high flatts
# 428                       flint hill
# 429                      foggy furze
# 430                       follingsby
# 431                       fondly set
# 432                        high ford
# 433                             ford
# 434                 forest and frith
# 435               forest-in-teesdale
# 436                   four lane ends
# 437                            frame
# 438                framwellgate moor
# 439                      newton hall
# 440                     friars goose
# 441                   high friarside
# 442                    low friarside
# 443                       frosterley
# 444                        fugar bar
# 445                          fulwell
# 446                         gainford
# 447                  galloping green
# 448                 garmondsway moor
# 449                        hop garth
# 450                            garth
# 451                   gateshead fell
# 452                        gateshead
# 453                          gibside
# 454                   gilesgate moor
# 455                        gilesgate
# 456                    rowlands gill
# 457                           girsby
# 458                            glebe
# 459                        goosepool
# 460                      gordon gill
# 461                      grange hill
# 462                     grange villa
# 463                      grangefield
# 464                       grangetown
# 465                        grasswell
# 466                        graythorp
# 467                   great aycliffe
# 468                     great burdon
# 469                     great lumley
# 470                   great stainton
# 471                    great usworth
# 472               greater willington
# 473                         greatham
# 474                       green head
# 475                   new greencroft
# 476                       greencroft
# 477                        greenside
# 478                   greenwell ford
# 479                          grindon
# 480                        the grove
# 481                        hallgarth
# 482                        hamsteels
# 483                  hamsterley mill
# 484                       hamsterley
# 485                  high handenhold
# 486                harbourhouse park
# 487                         hardwick
# 488                          harelaw
# 489                    harewood hill
# 490                     harlow green
# 491                          harmire
# 492                   harperley dean
# 493                        harperley
# 494                         harraton
# 495                  harrowgate hill
# 496               harrowgate village
# 497                     hart station
# 498                             hart
# 499                         hartburn
# 500                       hartlepool
# 501                  harton colliery
# 502                      harton nook
# 503                      west harton
# 504                           harton
# 505                    hartside farm
# 506                          harwood
# 507                    hastings hill
# 508                     haswell moor
# 509                   haswell plough
# 510                          haswell
# 511         haughton and springfield
# 512               haughton le skerne
# 513               haughton le skerne
# 514                         havannah
# 515                    haverton hill
# 516                    hawkwell head
# 517                         hawthorn
# 518                          headlam
# 519             headland and harbour
# 520                         headland
# 521                      healeyfield
# 522                   heatherycleugh
# 523                 hebburn colliery
# 524               hebburn hall ponds
# 525                 hebburn new town
# 526                    hebburn north
# 527                     hebburn quay
# 528                      hebburn row
# 529                    hebburn south
# 530                          hebburn
# 531                       hedgefield
# 532                      hedley hill
# 533                       hedleyhope
# 534                         hedworth
# 535      heighington and coniscliffe
# 536                      heighington
# 537                   helmington row
# 538                           hendon
# 539                  herrington burn
# 540                middle herrington
# 541                   new herrington
# 542                  west herrington
# 543                         hertburn
# 544                    high hesleden
# 545                         hesleden
# 546                    hesledon bank
# 547                       hett hills
# 548                             hett
# 549                  hetton colliery
# 550                     hetton downs
# 551                   hetton le hill
# 552                     south hetton
# 553                   hetton-le-hole
# 554                           hetton
# 555                   heworth grange
# 556                     high heworth
# 557                          heworth
# 558                      high barnes
# 559                   high beechburn
# 560                    high colliery
# 561                 high coniscliffe
# 562                        high dike
# 563                      high escomb
# 564                    high etherley
# 565                        high fell
# 566                      high grange
# 567                       high lands
# 568                    high moorsley
# 569                     high newport
# 570                  high pittington
# 571                     high shields
# 572                  high shincliffe
# 573                   high southwick
# 574                        high spen
# 575                  high springwell
# 576                   high swainston
# 577                        high team
# 578                    high thornley
# 579                    high throston
# 580                    high tunstall
# 581                      high urpeth
# 582                     high usworth
# 583               high west thickley
# 584                    high westwood
# 585                        high wham
# 586                        highfield
# 587                         hill end
# 588                         hill top
# 589                         hillview
# 590                           hilton
# 591                           hobson
# 592                     west holborn
# 593                 holmlands estate
# 594                   holmlands park
# 595                         holmside
# 596                      hooker gate
# 597                        hope town
# 598                  horden colliery
# 599                           horden
# 600                     horsley hill
# 601                     horsley vale
# 602                         houghall
# 603                    houghton bank
# 604                    houghton gate
# 605                 houghton-le-side
# 606               houghton-le-spring
# 607                         houghton
# 608                   howden le wear
# 609                            howle
# 610                          howlish
# 611                         hudegate
# 612                        humbledon
# 613                       hummerbeck
# 614                     hummersknott
# 615                     hunstanworth
# 616                      new hunwick
# 617                          hunwick
# 618                    hurworth burn
# 619                   hurworth place
# 620                 hurworth-on-tees
# 621                         hurworth
# 622                     hutton henry
# 623                    hylton castle
# 624                 hylton red house
# 625                           hylton
# 626                         ingleton
# 627                         inkerman
# 628                     ireshopeburn
# 629                          iveston
# 630                           jarrow
# 631                   low job's hill
# 632                       kelloe law
# 633                      town kelloe
# 634                           kelloe
# 635                     kibblesworth
# 636                         killerby
# 637                         killhope
# 638                  killinghall row
# 639                     kimblesworth
# 640                        kinninvie
# 641                         kip hill
# 642                          kiphill
# 643                  kirk merrington
# 644                    white kirkley
# 645                 knitsley station
# 646                     low knitsley
# 647                         knitsley
# 648                          new kyo
# 649                         west kyo
# 650                        lady park
# 651                      low lambton
# 652                      new lambton
# 653                          lambton
# 654                         lamesley
# 655                       lanchester
# 656                        lane ends
# 657                        lane head
# 658                         lanehead
# 659                     langdon beck
# 660                     langley moor
# 661                     langley park
# 662          langleydale and shotton
# 663                          langton
# 664                   laygate street
# 665                     south layton
# 666                      west layton
# 667                         leadgate
# 668                        leam lane
# 669                             leam
# 670                         leamside
# 671                    leasingthorne
# 672                           leazes
# 673                        leechmere
# 674                         leeholme
# 675                        lemington
# 676                     lilley drift
# 677                        lingfield
# 678                      lintz green
# 679                            lintz
# 680                        lintzford
# 681                       lintzgarth
# 682                    little lumley
# 683                   little newsham
# 684                  little stainton
# 685                    little thorpe
# 686                   little usworth
# 687                       littleburn
# 688                       littletown
# 689                      lobley hill
# 690                      long acre's
# 691                        long acre
# 692                         longhill
# 693                       longnewton
# 694                     lookout hill
# 695                    low beechburn
# 696                  low coniscliffe
# 697                      low eighton
# 698                    low greenside
# 699                        low lands
# 700                     low moorsley
# 701                   low pittington
# 702                    low simonside
# 703                    low southwick
# 704                         low spen
# 705                   low spennymoor
# 706                    low swainston
# 707                         low team
# 708                     low thornley
# 709                     low tunstall
# 710                low west thickley
# 711                     low westwood
# 712                   low willington
# 713                      lowe's barn
# 714                         ludworth
# 715                    lumley thicks
# 716                           lumley
# 717                        lyndhurst
# 718             lynesack and softley
# 719                         lynesack
# 720                            lyons
# 721                      lyric lodge
# 722                       maiden law
# 723                       mainsforth
# 724                  malton colliery
# 725                           malton
# 726                      manor house
# 727                      marley hill
# 728                      marley pots
# 729                          marsden
# 730                   marshall green
# 731                          marwood
# 732                      meadowfield
# 733                   medomsley edge
# 734                  south medomsley
# 735                        medomsley
# 736                  merrington lane
# 737                       merrington
# 738                        merrybent
# 739                        merryoaks
# 740                     metal bridge
# 741                   middle rainton
# 742                      middle side
# 743                 middle swainston
# 744                      middlefield
# 745                      the middles
# 746                    middlesbrough
# 747                 middlestone moor
# 748                      middlestone
# 749                middleton one row
# 750              middleton st george
# 751            middleton-in-teesdale
# 752                        middleton
# 753                 middridge grange
# 754                        middridge
# 755                     milkwellburn
# 756                         mill dam
# 757                        mill hill
# 758                        millfield
# 759                    monk hesleden
# 760                          monkton
# 761              monkwearmouth shore
# 762                    monkwearmouth
# 763                       south moor
# 764                        town moor
# 765                         moorside
# 766                         moorsley
# 767                mordon south side
# 768                           mordon
# 769                           morley
# 770                    morton grange
# 771                     morton palms
# 772                  morton tinmouth
# 773                   mount pleasant
# 774                        mountsett
# 775                           mowden
# 776                      muggleswick
# 777                           murton
# 778                  murton colliery
# 779                      murton moor
# 780                 musgrave gardens
# 781                         mushroom
# 782                          neasham
# 783                          nesbitt
# 784                     nettlesworth
# 785                      new penshaw
# 786                   new pittington
# 787                      new shildon
# 788                   new silksworth
# 789                         new town
# 790                   new washington
# 791                        newbiggin
# 792                        newbottle
# 793              newcastle upon tyne
# 794                         newfield
# 795                      newlandside
# 796                          newsham
# 797                    newton bewley
# 798                  newton cap bank
# 799                       newton cap
# 800                    newton ketton
# 801                          newtown
# 802                         no place
# 803                       urlay nook
# 804                     north bridge
# 805                      north close
# 806                        north end
# 807                       north hill
# 808                     north hylton
# 809                      north lodge
# 810                  north parkfield
# 811              north richmondshire
# 812                       north road
# 813                  north roddymoor
# 814                       north side
# 815                        northgate
# 816                       northgrain
# 817                         northlea
# 818                           norton
# 819                      nunstainton
# 820                         oak tree
# 821                        oakenshaw
# 822                        oaks bank
# 823                      oakwellgate
# 824                         offerton
# 825                         old fold
# 826                         old park
# 827                  old quarrington
# 828                  old ravensworth
# 829                  old stillington
# 830                    old sunniside
# 831                     old thornley
# 832                      old wingate
# 833                      ornsby hill
# 834                     osmond croft
# 835                           ouston
# 836                    over dinsdale
# 837                      owton manor
# 838                            owton
# 839                         oxbridge
# 840                          oxclose
# 841                   oxen-le-fields
# 842                           oxhill
# 843                       oxneyfield
# 844                        page bank
# 845                          pallion
# 846                        park east
# 847                      park estate
# 848                        park west
# 849           parkfield and oxbridge
# 850                         parkside
# 851                        passfield
# 852                        path head
# 853                        pattinson
# 854                     pelaw grange
# 855                      south pelaw
# 856                            pelaw
# 857                      pelton fell
# 858                 pelton lane ends
# 859                      west pelton
# 860                           pelton
# 861                        pennywell
# 862                  penshaw staiths
# 863                      old penshaw
# 864                          penshaw
# 865                     perkinsville
# 866                    peterlee east
# 867                    peterlee west
# 868                         peterlee
# 869                     philadelphia
# 870                      phoenix row
# 871                   pickering nook
# 872                         picktree
# 873                     piercebridge
# 874                       pierremont
# 875                          pilmore
# 876                       pittington
# 877                          pity me
# 878                      plains farm
# 879                  plawsworth gate
# 880                       plawsworth
# 881                           pontop
# 882                       portobello
# 883                         portrack
# 884                preston-le-skerne
# 885                  preston-on-tees
# 886                    primrose hill
# 887                         primrose
# 888                    prudhoe south
# 889                   quaking houses
# 890                 quarrington hill
# 891                      quarry burn
# 892                           quebec
# 893                      raby castle
# 894                      raby estate
# 895             raby with keverstone
# 896                         ragworth
# 897                   rainton bridge
# 898                     rainton gate
# 899                          ramshaw
# 900                      ravensworth
# 901                             real
# 902                         red hall
# 903                        red hills
# 904                        red house
# 905                         redheugh
# 906                          redhill
# 907                      redmarshall
# 908                         redworth
# 909                    richmondshire
# 910                        rickleton
# 911                       rift house
# 912                         the rift
# 913                 rifthouse estate
# 914                        rise carr
# 915                   west roddymoor
# 916                        roddymoor
# 917                            roker
# 918                         rookhope
# 919                        roseworth
# 920                         rossmere
# 921                           rowley
# 922                        royal oak
# 923                        rudd hill
# 924                         ruffside
# 925                       rumby hill
# 926                         run head
# 927                       rural west
# 928                        rushyford
# 929                  ryhope colliery
# 930                           ryhope
# 931                      ryton haugh
# 932                   ryton woodside
# 933                            ryton
# 934                        sacriston
# 935                         sadberge
# 936                     salt meadows
# 937                        saltholme
# 938                    saltwell side
# 939                         saltwell
# 940                         sandhill
# 941                           satley
# 942                    sawmills lane
# 943                          seaburn
# 944                           seaham
# 945                     seaton carew
# 946               seaton lane estate
# 947             seaton with slingley
# 948                           seaton
# 949                       sedgefield
# 950                       sedgeletch
# 951                        shadforth
# 952                       west shaws
# 953                       sheep hill
# 954              sheraton with hulam
# 955                         sheraton
# 956                         sherburn
# 957                    sherburn hill
# 958                 sherburn village
# 959                     sheriff hill
# 960                       shield row
# 961                        shieldrow
# 962                    south shields
# 963                          shildon
# 964              shincliffe bank top
# 965                       shincliffe
# 966                       shiney row
# 967                         shipcote
# 968                   shotley bridge
# 969                 shotton colliery
# 970                          shotton
# 971              silksworth colliery
# 972                       silksworth
# 973          simonside and rekendyke
# 974                        simonside
# 975                       simpasture
# 976                      skerne park
# 977                      skerningham
# 978                        the slack
# 979                        snaisgill
# 980                   sniperley park
# 981                     snow's green
# 982                    sourmilk hill
# 983                    south bedburn
# 984                     south church
# 985                       south hill
# 986                     south hylton
# 987                      south shore
# 988                       south side
# 989                    south stanley
# 990                   south tynedale
# 991                   south tyneside
# 992                    south wardley
# 993                        southwick
# 994                             spen
# 995                       spennymoor
# 996                      springfield
# 997                  springwell park
# 998                       springwell
# 999                        st anne's
# 1000                       st chad's
# 1001                st john's chapel
# 1002                    st michael's
# 1003                      st peter's
# 1004                   st ann's hill
# 1005                        st hilda
# 1006               st oswald's drive
# 1007                       staindrop
# 1008                  stainton grove
# 1009                        stanhope
# 1010                         stanley
# 1011                   stanley crook
# 1012                        stargate
# 1013                    station town
# 1014                          stella
# 1015                      stephenson
# 1016                     stillington
# 1017                      stob house
# 1018                        stockley
# 1019                 stockton grange
# 1020            stockton town centre
# 1021                stockton-on-tees
# 1022                      stones end
# 1023                      stony gate
# 1024                      stony heap
# 1025                  stotfield burn
# 1026                        stranton
# 1027          streatlam and stainton
# 1028                     street gate
# 1029                         success
# 1030                        sulgrave
# 1031              summerhouse square
# 1032                     summerhouse
# 1033               sunderland bridge
# 1034                      sunderland
# 1035                       sunniside
# 1036                      sunny brow
# 1037                       sunnybrow
# 1038                       sunnydale
# 1039                        swalwell
# 1040                    swinhopeburn
# 1041                       tan hills
# 1042                    tanfield lea
# 1043                        tanfield
# 1044                        tantobie
# 1045                       teal farm
# 1046                   team colliery
# 1047                     team valley
# 1048                           teams
# 1049                        teesside
# 1050                      templetown
# 1051                        the lawe
# 1052                        the loup
# 1053                        thickley
# 1054                        thinford
# 1055                   thorney close
# 1056                        thornlaw
# 1057                        thornley
# 1058                   thorpe bulmer
# 1059                  thorpe larches
# 1060                  thorpe thewles
# 1061          throston grange estate
# 1062                        throston
# 1063                        todhills
# 1064                       toft hill
# 1065                         toronto
# 1066                         tow law
# 1067                   town end farm
# 1068                   trafford hill
# 1069                trimdon colliery
# 1070                 trimdon foundry
# 1071                  trimdon grange
# 1072                         trimdon
# 1073                 tudhoe colliery
# 1074                   tudhoe grange
# 1075                  tudhoe village
# 1076                          tudhoe
# 1077                        tunstall
# 1078               tursdale junction
# 1079                        tursdale
# 1080                twizell colliery
# 1081                    twizell wood
# 1082                       tyne dock
# 1083                      upper town
# 1084                          urpeth
# 1085                      ushaw moor
# 1086                         usworth
# 1087             victoria garesfield
# 1088                        victoria
# 1089                            vigo
# 1090              washington village
# 1091                     wackerfield
# 1092                  waldridge fell
# 1093                       waldridge
# 1094                      walkergate
# 1095                       wall nook
# 1096                 wallace village
# 1097                   walworth gate
# 1098                        walworth
# 1099                      warden law
# 1100                wardley colliery
# 1101                         wardley
# 1102              washington central
# 1103                 washington east
# 1104                      washington
# 1105                  waskerley park
# 1106                       waskerley
# 1107                       watergate
# 1108                     waterhouses
# 1109                        waterloo
# 1110        watling street bungalows
# 1111                        weardale
# 1112                        wearhead
# 1113              wearmouth colliery
# 1114                       wellfield
# 1115                  west butsfield
# 1116                  west cornforth
# 1117                       west park
# 1118                    west rainton
# 1119                       west view
# 1120                    western hill
# 1121                       westerton
# 1122                        westgate
# 1123                         westlea
# 1124                  westoe village
# 1125                          westoe
# 1126                        westwick
# 1127                        westwood
# 1128                    wharton park
# 1129                     wheatbottom
# 1130                   wheatley hill
# 1131                         whessoe
# 1132                  whickham north
# 1133    whickham south and sunniside
# 1134                        whickham
# 1135                     whin houses
# 1136                       whinfield
# 1137                    whinney hill
# 1138               whitburn colliery
# 1139                        whitburn
# 1140                      white leas
# 1141                   white-le-head
# 1142                       whitehill
# 1143                       whiteleas
# 1144                     whitesmocks
# 1145                         whitton
# 1146                  whitworth park
# 1147                       whitworth
# 1148                        whorlton
# 1149                      willington
# 1150                       wind mill
# 1151                     windlestone
# 1152       windy nook and whitehills
# 1153                      windy nook
# 1154                  wingate grange
# 1155                    wingate lane
# 1156                         wingate
# 1157                   winlaton mill
# 1158                        winlaton
# 1159                         winston
# 1160                       winterton
# 1161                      witherwack
# 1162                  witton bottoms
# 1163                  witton gilbert
# 1164                     witton park
# 1165                  witton-le-wear
# 1166                     wolf cleugh
# 1167                      wolsingham
# 1168                       wolviston
# 1169                     wood houses
# 1170                 woodham village
# 1171                         woodham
# 1172                 woodhouse close
# 1173                      woodhouses
# 1174                        woodland
# 1175                        woodside
# 1176               woodstone village
# 1177                       wrekenton
# 1178                 wynward station
# 1179                    wynyard hall
# 1180                    wynyard park
# 1181                 wynyard village
# 1182                         wynyard

# %%
durham_df.to_csv('place_names_durham.txt', sep='\t', index=False, header=False)

# %%
with open('place_names_UK.txt', 'r', encoding='utf-8') as f:
    places = f.read().splitlines()
